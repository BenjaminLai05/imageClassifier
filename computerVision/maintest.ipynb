# %%
pip install opencv-python ultralytics
# Out:
# Requirement already satisfied: opencv-python in /opt/anaconda3/lib/python3.12/site-packages (4.11.0.86)
# Requirement already satisfied: ultralytics in /opt/anaconda3/lib/python3.12/site-packages (8.3.105)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/lib/python3.12/site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (3.8.4)
# Requirement already satisfied: pillow>=7.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.32.2)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.6.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (0.21.0)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2024.7.4)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2024.3.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (69.5.1)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
model = YOLO("yolo-Weights/yolov8n.pt")

# %%
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

# %%
import cv2
import math

cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

while True:
    ret, img = cap.read()

    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)
            
    cv2.imshow('Webcam', cv2.flip(img, 1))
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 72.4ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 2.4ms preprocess, 72.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 57.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.44
# Class name --> sofa
# Speed: 1.0ms preprocess, 57.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 146.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.49
# Class name --> sofa
# Speed: 4.9ms preprocess, 146.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 72.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.46
# Class name --> sofa
# Speed: 1.1ms preprocess, 72.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 53.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.41
# Class name --> sofa
# Confidence ---> 0.26
# Class name --> sofa
# Speed: 1.1ms preprocess, 53.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 54.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.46
# Class name --> sofa
# Confidence ---> 0.28
# Class name --> sofa
# Speed: 0.9ms preprocess, 54.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 52.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.48
# Class name --> sofa
# Confidence ---> 0.29
# Class name --> sofa
# Speed: 1.0ms preprocess, 52.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 57.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.59
# Class name --> sofa
# Confidence ---> 0.29
# Class name --> sofa
# Speed: 1.0ms preprocess, 57.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 59.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.62
# Class name --> sofa
# Confidence ---> 0.28
# Class name --> sofa
# Speed: 1.2ms preprocess, 59.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 56.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.67
# Class name --> sofa
# Speed: 2.5ms preprocess, 56.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 49.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.68
# Class name --> sofa
# Speed: 0.8ms preprocess, 49.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 52.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.69
# Class name --> sofa
# Speed: 1.2ms preprocess, 52.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 49.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.69
# Class name --> sofa
# Speed: 0.9ms preprocess, 49.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 51.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.65
# Class name --> sofa
# Speed: 1.2ms preprocess, 51.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 50.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.69
# Class name --> sofa
# Confidence ---> 0.26
# Class name --> sofa
# Speed: 0.9ms preprocess, 50.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 52.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.68
# Class name --> sofa
# Speed: 1.1ms preprocess, 52.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 47.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.71
# Class name --> sofa
# Confidence ---> 0.26
# Class name --> sofa
# Speed: 1.0ms preprocess, 47.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 49.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.69
# Class name --> sofa
# Speed: 0.9ms preprocess, 49.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 49.7ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.46
# Class name --> sofa
# Speed: 1.0ms preprocess, 49.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 45.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.5
# Class name --> sofa
# Confidence ---> 0.3
# Class name --> sofa
# Speed: 1.0ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 52.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.53
# Class name --> sofa
# Speed: 0.8ms preprocess, 52.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 51.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.41
# Class name --> sofa
# Speed: 1.2ms preprocess, 51.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 46.2ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.44
# Class name --> sofa
# Speed: 1.0ms preprocess, 46.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 48.9ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.49
# Class name --> sofa
# Speed: 1.1ms preprocess, 48.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 51.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.56
# Class name --> sofa
# Speed: 0.9ms preprocess, 51.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 44.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.53
# Class name --> sofa
# Speed: 0.8ms preprocess, 44.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 51.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.62
# Class name --> sofa
# Speed: 1.0ms preprocess, 51.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 47.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.55
# Class name --> sofa
# Speed: 1.0ms preprocess, 47.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 49.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.49
# Class name --> sofa
# Speed: 1.1ms preprocess, 49.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 48.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.51
# Class name --> sofa
# Speed: 0.9ms preprocess, 48.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 48.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.54
# Class name --> sofa
# Speed: 0.9ms preprocess, 48.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 49.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.54
# Class name --> sofa
# Speed: 0.8ms preprocess, 49.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 47.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.36
# Class name --> sofa
# Speed: 0.9ms preprocess, 47.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 46.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.47
# Class name --> sofa
# Speed: 1.2ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 54.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.4
# Class name --> sofa
# Speed: 0.9ms preprocess, 54.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 49.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.45
# Class name --> sofa
# Speed: 0.9ms preprocess, 49.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 44.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.48
# Class name --> sofa
# Speed: 1.0ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 48.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.44
# Class name --> sofa
# Speed: 0.9ms preprocess, 48.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 61.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.51
# Class name --> sofa
# Speed: 1.4ms preprocess, 61.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 52.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.55
# Class name --> sofa
# Speed: 1.0ms preprocess, 52.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 54.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.53
# Class name --> sofa
# Speed: 1.2ms preprocess, 54.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 46.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.48
# Class name --> sofa
# Speed: 1.3ms preprocess, 46.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 41.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.5
# Class name --> sofa
# Speed: 1.2ms preprocess, 41.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 43.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.54
# Class name --> sofa
# Speed: 1.2ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 41.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.48
# Class name --> sofa
# Speed: 0.9ms preprocess, 41.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 40.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.49
# Class name --> sofa
# Speed: 0.8ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 41.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.49
# Class name --> sofa
# Speed: 1.0ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 41.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.41
# Class name --> sofa
# Speed: 0.8ms preprocess, 41.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 41.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.39
# Class name --> sofa
# Speed: 1.2ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 40.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.41
# Class name --> sofa
# Speed: 0.9ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 couch, 41.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.39
# Class name --> sofa
# Confidence ---> 0.34
# Class name --> person
# Speed: 0.9ms preprocess, 41.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 couch, 40.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.37
# Class name --> sofa
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.8ms preprocess, 40.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 couch, 43.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.36
# Class name --> sofa
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.0ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 couch, 41.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.35
# Class name --> sofa
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.1ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 42.5ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.37
# Class name --> sofa
# Speed: 0.9ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 couch, 41.2ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.33
# Class name --> sofa
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.0ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 couch, 39.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.35
# Class name --> sofa
# Confidence ---> 0.33
# Class name --> person
# Speed: 0.9ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 43.0ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.39
# Class name --> sofa
# Speed: 0.8ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 42.0ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.38
# Class name --> sofa
# Speed: 1.1ms preprocess, 42.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 39.4ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.37
# Class name --> sofa
# Speed: 0.9ms preprocess, 39.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.9ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.9ms preprocess, 40.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.1ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.1ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.0ms preprocess, 41.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.1ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.9ms preprocess, 42.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 41.5ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.0ms preprocess, 41.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 44.3ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 0.8ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 49.5ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.1ms preprocess, 49.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 42.1ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.3ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 45.9ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.3ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 41.1ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Speed: 0.9ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 41.8ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 0.9ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 41.2ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 1.0ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 43.0ms
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.2ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 40.9ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.0ms preprocess, 40.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 remote, 41.1ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.26
# Class name --> remote
# Speed: 0.8ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 40.3ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.9ms preprocess, 40.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 43.3ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Speed: 1.0ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 44.0ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.2ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 40.6ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.1ms preprocess, 40.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 40.7ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
# Speed: 0.8ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 41.8ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.0ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 41.1ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.34
# Class name --> chair
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.8ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 49.2ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.6ms preprocess, 49.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 45.8ms
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Speed: 1.3ms preprocess, 45.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 41.4ms
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.1ms preprocess, 41.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 43.8ms
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 1.0ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 46.4ms
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.9ms preprocess, 46.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 49.7ms
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Speed: 1.6ms preprocess, 49.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 41.2ms
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.1ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 41.3ms
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 1.0ms preprocess, 41.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 41.4ms
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.9ms preprocess, 41.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 44.7ms
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.9ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 42.7ms
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Speed: 1.2ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 44.5ms
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.1ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 42.5ms
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.0ms preprocess, 42.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 41.9ms
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.9ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 42.2ms
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 0.9ms preprocess, 42.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 43.1ms
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.2ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 41.1ms
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.1ms preprocess, 41.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 41.5ms
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 0.8ms preprocess, 41.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 42.1ms
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.8ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 40.7ms
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 0.9ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 42.7ms
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.0ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 40.7ms
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 0.8ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 40.5ms
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 0.8ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 40.6ms
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 0.9ms preprocess, 40.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 40.9ms
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.9ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.3ms
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.3ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Confidence ---> 0.52
# Class name --> person
# Speed: 1.0ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 41.3ms
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 0.9ms preprocess, 41.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.0ms preprocess, 42.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.5ms
# Confidence ---> 0.6
# Class name --> person
# Speed: 1.6ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 83.3ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 34.5ms preprocess, 83.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.8ms
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.1ms preprocess, 57.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.7ms
# Confidence ---> 0.57
# Class name --> person
# Speed: 1.2ms preprocess, 53.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.2ms
# Confidence ---> 0.62
# Class name --> person
# Speed: 1.1ms preprocess, 62.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.1ms
# Confidence ---> 0.65
# Class name --> person
# Speed: 2.2ms preprocess, 60.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.7ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.1ms preprocess, 56.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.2ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 1.1ms preprocess, 50.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 48.3ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.8ms preprocess, 48.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 48.6ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.1ms preprocess, 48.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 52.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.3ms preprocess, 52.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.9ms preprocess, 55.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 54.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 45.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 48.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.2ms preprocess, 48.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 49.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Speed: 1.0ms preprocess, 49.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 53.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 0.8ms preprocess, 53.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 49.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.1ms preprocess, 49.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 51.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.1ms preprocess, 50.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 49.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.37
# Class name --> sofa
# Speed: 0.9ms preprocess, 49.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 50.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.51
# Class name --> sofa
# Speed: 0.9ms preprocess, 50.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 51.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.37
# Class name --> sofa
# Speed: 0.9ms preprocess, 51.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 52.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.34
# Class name --> sofa
# Speed: 1.0ms preprocess, 52.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.2ms preprocess, 53.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 53.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.4
# Class name --> sofa
# Speed: 1.1ms preprocess, 53.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 53.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.32
# Class name --> sofa
# Speed: 1.1ms preprocess, 53.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.6ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.9ms preprocess, 40.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.2ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 42.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.29
# Class name --> sofa
# Speed: 1.2ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 44.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.48
# Class name --> sofa
# Speed: 0.8ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 3 couchs, 41.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.62
# Class name --> sofa
# Confidence ---> 0.35
# Class name --> sofa
# Confidence ---> 0.33
# Class name --> chair
# Confidence ---> 0.29
# Class name --> sofa
# Speed: 1.1ms preprocess, 41.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 42.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.58
# Class name --> sofa
# Speed: 0.8ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 40.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.51
# Class name --> sofa
# Confidence ---> 0.51
# Class name --> sofa
# Speed: 0.8ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 1 bed, 41.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.66
# Class name --> sofa
# Confidence ---> 0.43
# Class name --> sofa
# Confidence ---> 0.34
# Class name --> bed
# Speed: 1.1ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 41.9ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.56
# Class name --> sofa
# Confidence ---> 0.39
# Class name --> sofa
# Speed: 1.1ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 2 beds, 44.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.58
# Class name --> bed
# Confidence ---> 0.31
# Class name --> bed
# Confidence ---> 0.31
# Class name --> sofa
# Speed: 0.9ms preprocess, 44.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 41.3ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.53
# Class name --> sofa
# Confidence ---> 0.28
# Class name --> sofa
# Speed: 0.8ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 41.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.62
# Class name --> sofa
# Confidence ---> 0.33
# Class name --> sofa
# Speed: 0.9ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 50.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.67
# Class name --> sofa
# Confidence ---> 0.43
# Class name --> sofa
# Speed: 1.3ms preprocess, 50.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 46.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.46
# Class name --> sofa
# Confidence ---> 0.32
# Class name --> sofa
# Speed: 1.0ms preprocess, 46.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 1 bed, 42.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.47
# Class name --> sofa
# Confidence ---> 0.42
# Class name --> sofa
# Confidence ---> 0.39
# Class name --> bed
# Speed: 0.9ms preprocess, 42.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 1 bed, 44.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.35
# Class name --> bed
# Confidence ---> 0.34
# Class name --> sofa
# Speed: 1.2ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 1 bed, 48.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.5
# Class name --> bed
# Confidence ---> 0.44
# Class name --> sofa
# Confidence ---> 0.32
# Class name --> sofa
# Speed: 1.1ms preprocess, 48.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 1 bed, 44.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.47
# Class name --> bed
# Confidence ---> 0.42
# Class name --> sofa
# Confidence ---> 0.3
# Class name --> chair
# Speed: 1.1ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 2 beds, 39.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.52
# Class name --> bed
# Confidence ---> 0.33
# Class name --> sofa
# Confidence ---> 0.3
# Class name --> bed
# Speed: 0.9ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 41.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 beds, 41.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.42
# Class name --> bed
# Confidence ---> 0.34
# Class name --> bed
# Speed: 0.8ms preprocess, 41.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 41.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.42
# Class name --> sofa
# Speed: 0.8ms preprocess, 41.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 beds, 42.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.63
# Class name --> bed
# Confidence ---> 0.42
# Class name --> bed
# Speed: 1.3ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 40.9ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.51
# Class name --> bed
# Speed: 0.9ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.1ms preprocess, 43.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 42.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.27
# Class name --> bed
# Speed: 1.0ms preprocess, 42.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 beds, 40.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.32
# Class name --> bed
# Confidence ---> 0.26
# Class name --> bed
# Speed: 0.8ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.2ms preprocess, 45.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 44.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.32
# Class name --> bed
# Speed: 0.9ms preprocess, 44.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.8ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 0.9ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 42.1ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.27
# Class name --> bed
# Speed: 1.2ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 0.9ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 41.2ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.0ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 43.0ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 0.8ms preprocess, 43.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.8ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 0.9ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.3ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.4ms preprocess, 46.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 0.8ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.8ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.9ms preprocess, 40.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 0.9ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.9ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.3ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.2ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.8ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.8ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.4ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.0ms preprocess, 41.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.2ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.8ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.1ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.9ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.4ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.8ms preprocess, 41.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 90.7ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.32
# Class name --> cup
# Speed: 0.8ms preprocess, 90.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 57.7ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.1ms preprocess, 57.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.1ms
# Confidence ---> 0.62
# Class name --> person
# Speed: 0.9ms preprocess, 52.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.6ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 0.9ms preprocess, 59.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.8ms
# Confidence ---> 0.7
# Class name --> person
# Speed: 0.9ms preprocess, 54.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 58.3ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.3ms preprocess, 58.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.2ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.9ms preprocess, 46.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.6ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.9ms preprocess, 86.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.3ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.0ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.1ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.1ms preprocess, 44.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 0.9ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.1ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.1ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 42.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.53
# Class name --> sofa
# Speed: 0.8ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 47.8ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.61
# Class name --> sofa
# Speed: 1.0ms preprocess, 47.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 couchs, 42.6ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.64
# Class name --> sofa
# Confidence ---> 0.29
# Class name --> sofa
# Speed: 0.9ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 41.1ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.59
# Class name --> sofa
# Speed: 1.2ms preprocess, 41.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 42.7ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.62
# Class name --> sofa
# Speed: 1.2ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 39.7ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.69
# Class name --> sofa
# Speed: 1.0ms preprocess, 39.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 41.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.66
# Class name --> sofa
# Speed: 1.0ms preprocess, 41.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 43.2ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.64
# Class name --> sofa
# Speed: 0.9ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 41.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.71
# Class name --> sofa
# Speed: 0.8ms preprocess, 41.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 41.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.7
# Class name --> sofa
# Speed: 1.1ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 40.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.78
# Class name --> sofa
# Speed: 0.8ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 40.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.78
# Class name --> sofa
# Speed: 1.3ms preprocess, 40.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 42.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.74
# Class name --> sofa
# Speed: 1.0ms preprocess, 42.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 41.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.73
# Class name --> sofa
# ...
#
# 0: 480x640 1 person, 40.6ms
# Confidence ---> 0.68
# Class name --> person
# Speed: 0.9ms preprocess, 40.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 42.2ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.0ms preprocess, 42.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Confidence ---> 0.7
# Class name --> person
# Speed: 1.2ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.4ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 1.3ms preprocess, 53.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Confidence ---> 0.67
# Class name --> person
# Speed: 1.2ms preprocess, 42.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.9ms
# Confidence ---> 0.7
# Class name --> person
# Speed: 0.9ms preprocess, 40.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.0ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.1ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 41.6ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.31
# Class name --> chair
# Speed: 1.1ms preprocess, 41.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 42.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.33
# Class name --> sofa
# Speed: 0.8ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 42.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
# Speed: 0.9ms preprocess, 42.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.1ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.9ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.3ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 42.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.29
# Class name --> chair
# Speed: 1.1ms preprocess, 42.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 42.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.28
# Class name --> sofa
# Speed: 1.0ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 129.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.29
# Class name --> sofa
# Speed: 1.0ms preprocess, 129.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.1ms preprocess, 66.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 65.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.31
# Class name --> sofa
# Speed: 1.6ms preprocess, 65.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 2 couchs, 53.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.31
# Class name --> chair
# Confidence ---> 0.28
# Class name --> sofa
# Confidence ---> 0.27
# Class name --> sofa
# Speed: 0.9ms preprocess, 53.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 75.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.41
# Class name --> chair
# Confidence ---> 0.36
# Class name --> sofa
# Speed: 1.2ms preprocess, 75.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.8ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.9ms preprocess, 76.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.1ms preprocess, 59.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.2ms preprocess, 61.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 61.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.3ms preprocess, 61.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.0ms preprocess, 62.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.2ms preprocess, 50.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.1ms preprocess, 51.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 59.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.1ms preprocess, 59.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.4ms preprocess, 46.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 46.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.7ms preprocess, 46.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.4ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.2ms preprocess, 58.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 49.7ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.1ms preprocess, 49.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 47.3ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 1.0ms preprocess, 47.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 40.6ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.0ms preprocess, 40.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 42.6ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.3ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 47.7ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Speed: 0.9ms preprocess, 47.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 55.8ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 1.1ms preprocess, 55.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 41.2ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.8ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 41.9ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.0ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 44.9ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.4ms preprocess, 44.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 0.8ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 41.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.1ms preprocess, 41.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.9ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.1ms preprocess, 51.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.5ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.2ms preprocess, 87.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.4ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.0ms preprocess, 49.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 47.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.6ms preprocess, 47.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.1ms preprocess, 45.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.3ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.4ms preprocess, 44.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.9ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.0ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.9ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.3ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.6ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.9ms preprocess, 69.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 42.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.29
# Class name --> chair
# Speed: 1.2ms preprocess, 42.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.9ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.3ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.1ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 42.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.9ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 41.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.1ms preprocess, 41.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.3ms preprocess, 41.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.1ms preprocess, 42.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.9ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.4ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.9ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.8ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 41.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.0ms preprocess, 41.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 41.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.4
# Class name --> sofa
# Speed: 1.5ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 couch, 40.9ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.34
# Class name --> sofa
# Confidence ---> 0.27
# Class name --> cup
# Speed: 0.9ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 1 couch, 51.8ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.43
# Class name --> wine glass
# Confidence ---> 0.4
# Class name --> sofa
# Speed: 0.9ms preprocess, 51.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.9ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.1ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 41.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.29
# Class name --> cup
# Speed: 1.3ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.0ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.3ms preprocess, 53.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 42.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.32
# Class name --> sofa
# Speed: 0.9ms preprocess, 42.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.8ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.1ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
